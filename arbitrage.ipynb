# %%
import requests
import time

transaction_fee = 0.005
major_currencies = ["DOGE","LTC"]
ignore_currencies = []
minimum_transaction = {"BTC":0.0005, "USDT":1, "NZDT":1, "LTC":0.01, "DOGE":100}

try:
    markets = requests.get("https://www.cryptopia.co.nz/api/GetMarkets").json()
    if not markets["Success"]:
        exit()
except:
    exit()


class graph:
    """
    Directed Cyclical Digraph
    """
    def __init__(self):
        self.currencies = {} #dictionary that maps currency name to currency objects

        for i in markets['Data']:
            if i["Volume"] > 0:
                coin1, coin2 = i["Label"].split("/")
                if coin1 in ignore_currencies or coin2 in ignore_currencies:
                    continue
                if coin1 not in self.currencies.keys():
                    self.currencies[coin1] = node(coin1)
                if coin2 not in self.currencies.keys():
                    self.currencies[coin2] = node(coin2)

                self.currencies[coin1].addChildren(self.currencies[coin2], i["BidPrice"])
                self.currencies[coin2].addChildren(self.currencies[coin1], 1/i["AskPrice"])

    def __repr__(self):
        return str(self.currencies)

class node:
    def __init__(self, name):
        self.name = name
        self.children = {} #dictionary that maps transactions to their price (e.g, if 1 unit of X gives 10 units of Y then we have {Y:10})

    def __repr__(self):
        return self.name

    def addChildren(self, newNode, conversion_rate):
        self.children[newNode] = conversion_rate

    def printChildren(self):
        print(str(self.children))

accumulator = {}
calls = 0

def find_good_cycles(graph):
    for currency in major_currencies:
        dfs([graph.currencies[currency]], 1, max_depth = 4)

def dfs(visited, conversion_product, max_depth):
    global calls

    if(max_depth <= 0):
        return
    for nextNode, conversion_rate in visited[-1].children.items():
        p = (1 - transaction_fee)*conversion_rate*conversion_product

        if nextNode in visited:
            if len(visited) > 3 and visited[0] == nextNode and p > 1:
                calls += 1
                accumulator[tuple(visited + [nextNode])] = p
        else:
            newVisited = list(visited)
            newVisited.append(nextNode)
            dfs(newVisited, p, max_depth - 1)

g = graph()
start = time.time()
find_good_cycles(g)
end = time.time()

sorted_list = sorted(accumulator.items(), key=lambda kv: kv[1], reverse=True)
for item in sorted_list:
  print(item)

for item in sorted_list[0:2]:
    valid = True
    value = 0
    volume = 0

    for i in range(len(item[0])-1):
        coin1 = item[0][i]
        coin2 = item[0][i+1]

        orders = requests.get("https://www.cryptopia.co.nz/api/GetMarketOrderGroups/%s_%s/3" % (coin1, coin2)).json()
        if orders["Data"] == None:
            orders = requests.get("https://www.cryptopia.co.nz/api/GetMarketOrderGroups/%s_%s/3" % (coin2, coin1)).json()


        c1, c2 = orders["Data"][0]["Buy"][0]["Label"].split("_")
        ## Fulfill Sell Order
        if str(coin1) == c2:
            value = (1/orders["Data"][0]["Sell"][0]["Price"])
            if i == 0:
                volume = orders["Data"][0]["Sell"][0]["Volume"]
            else:
                if orders["Data"][0]["Sell"][0]["Volume"] > volume*value:
                    volume = volume*value
                else:
                    volume = orders["Data"][0]["Sell"][0]["Volume"]
        else:
            value = (orders["Data"][0]["Buy"][0]["Price"])
            if i == 0:
                volume = orders["Data"][0]["Buy"][0]["Total"]
            else:
                if orders["Data"][0]["Buy"][0]["Total"] > volume*value:
                    volume = volume*value
                else:
                    volume = orders["Data"][0]["Buy"][0]["Total"]

        value = (1 - transaction_fee) * value

#         print("BUY ORDER" + str(orders["Data"][0]["Buy"][0]))
#         print("SELL ORDER" + str(orders["Data"][0]["Sell"][0]))
#         print(value, volume)
#     print(item, valid)

print("Number of cycles found: ", len(accumulator))
print("Runtime", end - start)
# Out:
# ((DOGE, SOON, BTC, HAC, DOGE), 1.2325059810457037)
# ((DOGE, MUSIC, BTC, HAC, DOGE), 1.2004955608342447)
# ((DOGE, LINX, BTC, HAC, DOGE), 1.1867696777191787)
# ((DOGE, DZC, BTC, HAC, DOGE), 1.1780493203060416)
# ((DOGE, LTC, BTC, HAC, DOGE), 1.1775395600399332)
# ((LTC, BTC, HAC, DOGE, LTC), 1.1775395600399332)
# ((DOGE, ETN, BTC, HAC, DOGE), 1.177356773525967)
# ((DOGE, ETH, BTC, HAC, DOGE), 1.176130759520228)
# ((DOGE, XEM, BTC, HAC, DOGE), 1.1742777913012912)
# ((DOGE, ZEC, BTC, HAC, DOGE), 1.1737424697375582)
# ((DOGE, USDT, BTC, HAC, DOGE), 1.1736214982461892)
# ((DOGE, XVG, BTC, HAC, DOGE), 1.1734139103156274)
# ((DOGE, TRX, BTC, HAC, DOGE), 1.173100456279922)
# ((DOGE, RVN, BTC, HAC, DOGE), 1.1730779054535871)
# ((DOGE, GBX, BTC, HAC, DOGE), 1.172747465912849)
# ((DOGE, CNET, BTC, HAC, DOGE), 1.17221077540246)
# ((DOGE, BCH, BTC, HAC, DOGE), 1.171648218716391)
# ((DOGE, ETC, BTC, HAC, DOGE), 1.1709476459265382)
# ((DOGE, EOS, BTC, HAC, DOGE), 1.170608278272107)
# ((DOGE, TUSD, BTC, HAC, DOGE), 1.1695275196766275)
# ((DOGE, SUMO, BTC, HAC, DOGE), 1.16858211752231)
# ((DOGE, XMR, BTC, HAC, DOGE), 1.1677295397606107)
# ((DOGE, NEO, BTC, HAC, DOGE), 1.167544062731112)
# ((DOGE, DASH, BTC, HAC, DOGE), 1.1672260086337587)
# ((DOGE, ADA, BTC, HAC, DOGE), 1.1655093650168198)
# ((DOGE, ZCL, BTC, HAC, DOGE), 1.1650330786206944)
# ((DOGE, UNIT, BTC, HAC, DOGE), 1.1593333814758657)
# ((DOGE, ZRX, BTC, HAC, DOGE), 1.1539191347311866)
# ((DOGE, QAC, BTC, HAC, DOGE), 1.1517610379120273)
# ((DOGE, UBQ, BTC, HAC, DOGE), 1.1510936743826525)
# ((DOGE, DGB, BTC, HAC, DOGE), 1.1508303213912554)
# ((DOGE, PPC, BTC, HAC, DOGE), 1.1489977774621554)
# ((DOGE, RDD, BTC, HAC, DOGE), 1.1441271247956761)
# ((DOGE, MGO, BTC, HAC, DOGE), 1.1400157532995074)
# ((DOGE, FLASH, BTC, HAC, DOGE), 1.1383915022997448)
# ((DOGE, LUX, BTC, HAC, DOGE), 1.137023730983561)
# ((DOGE, BITG, BTC, HAC, DOGE), 1.1312907862276673)
# ((DOGE, DBIX, BTC, HAC, DOGE), 1.1304580196984622)
# ((DOGE, ENJ, BTC, HAC, DOGE), 1.1290508314936023)
# ((DOGE, OMG, BTC, HAC, DOGE), 1.128255140195114)
# ((DOGE, BWK, BTC, HAC, DOGE), 1.12609201758813)
# ((DOGE, NZDT, BTC, HAC, DOGE), 1.1260169551911554)
# ((DOGE, ANON, BTC, HAC, DOGE), 1.1245948769233518)
# ((DOGE, LGS, BTC, HAC, DOGE), 1.1242325879594506)
# ((DOGE, CTL, BTC, HAC, DOGE), 1.1228510751386958)
# ((DOGE, ELLA, BTC, HAC, DOGE), 1.1218492271312088)
# ((DOGE, NRG, BTC, HAC, DOGE), 1.1216003697874832)
# ((DOGE, ARC, BTC, HAC, DOGE), 1.1188335774965794)
# ((DOGE, ARK, BTC, HAC, DOGE), 1.1182296176215596)
# ((DOGE, $PAC, BTC, HAC, DOGE), 1.117142663629505)
# ((DOGE, ZEN, BTC, HAC, DOGE), 1.1162904244897243)
# ((DOGE, REP, BTC, HAC, DOGE), 1.1146911334440959)
# ((DOGE, OPC, BTC, HAC, DOGE), 1.1126021358445943)
# ((DOGE, SKR, BTC, HAC, DOGE), 1.112597741083517)
# ((DOGE, LOKI, BTC, HAC, DOGE), 1.1120402238300222)
# ((DOGE, GRFT, BTC, HAC, DOGE), 1.11093308617703)
# ((DOGE, EXP, BTC, HAC, DOGE), 1.1098073593820488)
# ((DOGE, ETHD, BTC, HAC, DOGE), 1.1092684553292926)
# ((DOGE, FANS, BTC, HAC, DOGE), 1.1070786161818438)
# ((DOGE, EFL, BTC, HAC, DOGE), 1.1049618947074167)
# ((DOGE, BEAN, BTC, HAC, DOGE), 1.1036973202430516)
# ((DOGE, UFR, BTC, HAC, DOGE), 1.102609778001205)
# ((DOGE, SEND, BTC, HAC, DOGE), 1.1007296870088688)
# ((DOGE, PHR, BTC, HAC, DOGE), 1.0980785646316389)
# ((DOGE, XMY, BTC, HAC, DOGE), 1.0967851633411259)
# ((DOGE, SKY, BTC, HAC, DOGE), 1.0922023054533962)
# ((DOGE, STRAT, BTC, HAC, DOGE), 1.091381642945396)
# ((DOGE, MINT, BTC, HAC, DOGE), 1.0908184905875609)
# ((DOGE, FTEC, BTC, HAC, DOGE), 1.0888769518182833)
# ((DOGE, BOLI, BTC, HAC, DOGE), 1.0886754118796802)
# ((DOGE, XPD, BTC, HAC, DOGE), 1.088553468245384)
# ((DOGE, BITS, BTC, HAC, DOGE), 1.0859423437267284)
# ((DOGE, ELC, BTC, HAC, DOGE), 1.0855929645143791)
# ((DOGE, ORE, BTC, HAC, DOGE), 1.083088701733043)
# ((DOGE, PLR, BTC, HAC, DOGE), 1.0830519964500085)
# ((DOGE, DOT, BTC, HAC, DOGE), 1.0810365853115105)
# ((DOGE, LINDA, BTC, HAC, DOGE), 1.079581163456681)
# ((DOGE, BTCS, BTC, HAC, DOGE), 1.0789122347057574)
# ((DOGE, HUZU, BTC, HAC, DOGE), 1.0774584603953883)
# ((DOGE, ZER, BTC, HAC, DOGE), 1.0624603603961535)
# ((DOGE, FTC, BTC, HAC, DOGE), 1.0606927540053075)
# ((DOGE, LPC, BTC, HAC, DOGE), 1.0590477793058064)
# ((DOGE, VITAE, BTC, HAC, DOGE), 1.0586039178005333)
# ((DOGE, BVB, BTC, HAC, DOGE), 1.057102016534565)
# ((DOGE, SOON, BTC, GAME, DOGE), 1.0550437843926463)
# ((DOGE, XXX, BTC, HAC, DOGE), 1.0518427488242745)
# ((DOGE, XBY, BTC, HAC, DOGE), 1.051133179236353)
# ((DOGE, DCN, BTC, HAC, DOGE), 1.0496248544995903)
# ((DOGE, PIVX, BTC, HAC, DOGE), 1.049289725329543)
# ((DOGE, CHESS, BTC, HAC, DOGE), 1.046040366843902)
# ((DOGE, DEV, BTC, HAC, DOGE), 1.044691892691867)
# ((DOGE, CMPCO, BTC, HAC, DOGE), 1.0395470131147064)
# ((DOGE, MSP, BTC, HAC, DOGE), 1.0374089354437508)
# ((DOGE, POT, BTC, HAC, DOGE), 1.0369267050057358)
# ((DOGE, ORME, BTC, HAC, DOGE), 1.0354574676765578)
# ((DOGE, GRS, BTC, HAC, DOGE), 1.035224758288718)
# ((DOGE, SOON, BTC, HLM, DOGE), 1.035208546543462)
# ((DOGE, SOON, BTC, UNIT, DOGE), 1.0338720544661073)
# ((DOGE, SOON, BTC, BTX, DOGE), 1.0337002742472354)
# ((DOGE, CEFS, BTC, HAC, DOGE), 1.0300636737657711)
# ((DOGE, GNT, BTC, HAC, DOGE), 1.0287311235463488)
# ((DOGE, CRM, BTC, HAC, DOGE), 1.0283140952503071)
# ((DOGE, DEM, BTC, HAC, DOGE), 1.028111499040542)
# ((DOGE, MUSIC, BTC, GAME, DOGE), 1.0276423799376004)
# ((DOGE, SOON, BTC, CDM, DOGE), 1.026976122183256)
# ((DOGE, LTCU, BTC, HAC, DOGE), 1.024298840170136)
# ((DOGE, VIVO, BTC, HAC, DOGE), 1.024129157017223)
# ((LTC, QAC, BTC, UNO, LTC), 1.0190952458461655)
# ((DOGE, SOON, BTC, WSP, DOGE), 1.0185282291265563)
# ((DOGE, SOON, BTC, SEND, DOGE), 1.0184256452438134)
# ((LTC, DOPE, BTC, UNO, LTC), 1.0178336035378563)
# ((DOGE, SOON, BTC, ZER, DOGE), 1.0176840432906666)
# ((DOGE, Q2C, BTC, HAC, DOGE), 1.0168944580373536)
# ((DOGE, SOON, BTC, ETC, DOGE), 1.0163390645645907)
# ((DOGE, SOON, BTC, ELLA, DOGE), 1.0159025307327236)
# ((DOGE, LINX, BTC, GAME, DOGE), 1.0158928161313756)
# ((DOGE, SOON, BTC, ETH, DOGE), 1.015638748646508)
# ((DOGE, RED, BTC, HAC, DOGE), 1.0155002089635425)
# ((DOGE, SOON, BTC, ARC, DOGE), 1.0148488328092118)
# ((DOGE, MARKS, BTC, HAC, DOGE), 1.0142911518494757)
# ((DOGE, SOON, BTC, USDT, DOGE), 1.014170817511631)
# ((DOGE, SOON, BTC, BCH, DOGE), 1.0136987136425912)
# ((LTC, DGB, BTC, UNO, LTC), 1.0134481280138896)
# ((LTC, DOGE, SOON, BTC, LTC), 1.0130861435197394)
# ((DOGE, SOON, BTC, LTC, DOGE), 1.0130861435197391)
# ((DOGE, SOON, BTC, NEO, DOGE), 1.0127070668119715)
# ((LTC, ETC, BTC, UNO, LTC), 1.0125933287484077)
# ((LTC, USDT, BTC, UNO, LTC), 1.0124200791092344)
# ((LTC, ETH, BTC, UNO, LTC), 1.0121484398783853)
# ((LTC, TRX, BTC, UNO, LTC), 1.0119885878281187)
# ((DOGE, SOON, BTC, XPD, DOGE), 1.0116922372643107)
# ((LTC, RVN, BTC, UNO, LTC), 1.0116166511137654)
# ((LTC, BCH, BTC, UNO, LTC), 1.0111190818408964)
# ((DOGE, SOON, BTC, ETN, DOGE), 1.0108178275871977)
# ((LTC, COPPER, BTC, UNO, LTC), 1.0104635967151592)
# ((LTC, LINX, BTC, UNO, LTC), 1.0104635967151587)
# ((LTC, ZEC, BTC, UNO, LTC), 1.010312607223816)
# ((DOGE, SOON, BTC, VITAE, DOGE), 1.0100522102788831)
# ((LTC, DASH, BTC, UNO, LTC), 1.0100152423663953)
# ((DOGE, SOON, BTC, ZEC, DOGE), 1.0098613367456823)
# ((DOGE, SOON, LTC, UNIT, DOGE), 1.0098175102054485)
# ((LTC, UNIT, DOGE, SOON, LTC), 1.0098175102054485)
# ((DOGE, SOON, BTC, EOS, DOGE), 1.0096713971717588)
# ((DOGE, WSP, BTC, HAC, DOGE), 1.009132723336436)
# ((DOGE, DZC, BTC, GAME, DOGE), 1.0084280581278429)
# ((DOGE, MUSIC, BTC, HLM, DOGE), 1.0083222992627512)
# ((DOGE, LTC, BTC, GAME, DOGE), 1.0079916956204322)
# ((LTC, BTC, GAME, DOGE, LTC), 1.0079916956204322)
# ((DOGE, ETN, BTC, GAME, DOGE), 1.007835227596425)
# ((DOGE, SOON, BTC, ADA, DOGE), 1.0077969345451154)
# ((DOGE, FONZ, BTC, HAC, DOGE), 1.0077918992569044)
# ((LTC, GBX, BTC, UNO, LTC), 1.0074248616206654)
# ((DOGE, SOON, BTC, BCF, DOGE), 1.0074238873053984)
# ((DOGE, MUSIC, BTC, UNIT, DOGE), 1.0070205183135073)
# ((DOGE, MUSIC, BTC, BTX, DOGE), 1.0068531995391026)
# ((DOGE, ETH, BTC, GAME, DOGE), 1.0067857410412073)
# ((LTC, UNIT, BTC, UNO, LTC), 1.0066782565914203)
# ((LTC, QAC, BTC, TAJ, LTC), 1.0065792041703063)
# ((LTC, EOS, BTC, UNO, LTC), 1.006497820360694)
# ((LTC, NEO, BTC, UNO, LTC), 1.006137808367618)
# ((DOGE, TOA, BTC, HAC, DOGE), 1.0060304163521987)
# ((DOGE, SOON, BTC, XMR, DOGE), 1.0058431503247625)
# ((LTC, LGS, BTC, UNO, LTC), 1.0057829787515558)
# ((LTC, DOPE, BTC, TAJ, LTC), 1.0053330567509933)
# ((DOGE, SOON, BTC, RDD, DOGE), 1.0051999386287387)
# ((DOGE, XEM, BTC, GAME, DOGE), 1.0051995721851277)
# ((LTC, DOT, BTC, UNO, LTC), 1.00485510311637)
# ((LTC, XVG, BTC, UNO, LTC), 1.004787429133039)
# ((DOGE, ZEC, BTC, GAME, DOGE), 1.0047413288198592)
# ((DOGE, USDT, BTC, GAME, DOGE), 1.0046377753912996)
# ((LTC, QAC, BTC, FLASH, LTC), 1.004566674360697)
# ((DOGE, XVG, BTC, GAME, DOGE), 1.0044600769791032)
# ((LTC, XMR, BTC, UNO, LTC), 1.0042696930404624)
# ((DOGE, TRX, BTC, GAME, DOGE), 1.004191755577707)
# ((DOGE, RVN, BTC, GAME, DOGE), 1.0041724517288626)
# ((DOGE, SOON, BTC, DASH, DOGE), 1.0041183736278039)
# ((DOGE, SOON, BTC, TRX, DOGE), 1.0039076688293183)
# ((DOGE, GBX, BTC, GAME, DOGE), 1.0038895904779361)
# ((LTC, EMD, BTC, UNO, LTC), 1.003853606811844)
# ((LTC, ETN, BTC, UNO, LTC), 1.0034964641214017)
# ((DOGE, CNET, BTC, GAME, DOGE), 1.0034301752735992)
# ((DOGE, ECA, BTC, HAC, DOGE), 1.0033444472752295)
# ((LTC, DOPE, BTC, FLASH, LTC), 1.003323018458016)
# ((DOGE, BCF, BTC, HAC, DOGE), 1.002964326292681)
# ((DOGE, BCH, BTC, GAME, DOGE), 1.0029486182311727)
# ((DOGE, BSD, BTC, HAC, DOGE), 1.0028255135176118)
# ((LTC, ZCL, BTC, UNO, LTC), 1.0025975966521672)
# ((DOGE, ETC, BTC, GAME, DOGE), 1.0023489173138418)
# ((DOGE, SOON, BTC, SKR, DOGE), 1.002257761298884)
# ((DOGE, EOS, BTC, GAME, DOGE), 1.0020584134623898)
# ((DOGE, TES, BTC, HAC, DOGE), 1.0014912589138572)
# ((LTC, ADA, BTC, UNO, LTC), 1.0014823316766357)
# ((DOGE, TUSD, BTC, GAME, DOGE), 1.0011332677380482)
# ((LTC, DGB, BTC, TAJ, LTC), 1.0010014415454316)
# ((DOGE, SOON, BTC, XVG, DOGE), 1.0008863772210954)
# ((LTC, QTUM, BTC, UNO, LTC), 1.0006249734871835)
# ((DOGE, SUMO, BTC, GAME, DOGE), 1.0003239891771296)
# ((DOGE, MUSIC, BTC, CDM, DOGE), 1.0003036859243024)
# ((LTC, MUSIC, BTC, UNO, LTC), 1.0001760714092356)
# ((LTC, ETC, BTC, TAJ, LTC), 1.000157140516768)
# ((LTC, XEM, BTC, UNO, LTC), 1.0001124330332645)
# ((LTC, SOON, BTC, UNO, LTC), 1.0000629421171408)
# Number of cycles found:  202
# Runtime 0.8145642280578613

# %%
import requests
import time

transaction_fee = 0.005
major_currencies = ["DOGE"]
ignore_currencies = []
minimum_transaction = {"BTC":0.0005, "USDT":1, "NZDT":1, "LTC":0.01, "DOGE":100}

try:
    markets = requests.get("https://www.cryptopia.co.nz/api/GetMarkets").json()
    if not markets["Success"]:
        exit()
except:
    exit()


class graph:
    """
    Directed Cyclical Digraph
    """
    def __init__(self):
        self.currencies = {} #dictionary that maps currency name to currency objects

        for i in markets['Data']:
            if i["Volume"] > 0:
                coin1, coin2 = i["Label"].split("/")
                if coin1 in ignore_currencies or coin2 in ignore_currencies:
                    continue
                if coin1 not in self.currencies.keys():
                    self.currencies[coin1] = node(coin1)
                if coin2 not in self.currencies.keys():
                    self.currencies[coin2] = node(coin2)

                self.currencies[coin1].addChildren(self.currencies[coin2], i["BidPrice"])
                self.currencies[coin2].addChildren(self.currencies[coin1], 1/i["AskPrice"])

    def __repr__(self):
        return str(self.currencies)

class node:
    def __init__(self, name):
        self.name = name
        self.children = {} #dictionary that maps transactions to their price (e.g, if 1 unit of X gives 10 units of Y then we have {Y:10})

    def __repr__(self):
        return self.name

    def addChildren(self, newNode, conversion_rate):
        self.children[newNode] = conversion_rate

    def printChildren(self):
        print(str(self.children))

accumulator = {}
calls = 0

def find_good_cycles(graph):
    for currency in major_currencies:
        dfs([graph.currencies[currency]], 1, max_depth = 4)

def dfs(visited, conversion_product, max_depth):
    global calls

    if(max_depth <= 0):
        return
    for nextNode, conversion_rate in visited[-1].children.items():
        p = (1 - transaction_fee)*conversion_rate*conversion_product

        if nextNode in visited:
            if len(visited) > 3 and visited[0] == nextNode and p > 1:
                calls += 1
                accumulator[tuple(visited + [nextNode])] = p
        else:
            newVisited = list(visited)
            newVisited.append(nextNode)
            dfs(newVisited, p, max_depth - 1)

g = graph()
start = time.time()
find_good_cycles(g)
end = time.time()

sorted_list = sorted(accumulator.items(), key=lambda kv: kv[1], reverse=False)

for item in sorted_list[2:]:
    valid = True
    value = 0
    volume = 0

    for i in range(len(item[0])):
        if i == len(item[0])-1:
            print("great success")
            print(item)
            quit()
            break
        else:
            coin1 = item[0][i]
            coin2 = item[0][i+1]

            orders = requests.get("https://www.cryptopia.co.nz/api/GetMarketOrderGroups/%s_%s/3" % (coin1, coin2)).json()
            if orders["Data"] == None:
                orders = requests.get("https://www.cryptopia.co.nz/api/GetMarketOrderGroups/%s_%s/3" % (coin2, coin1)).json()

            c1, c2 = orders["Data"][0]["Buy"][0]["Label"].split("_")
        ## Fulfill Sell Order
        if i == 0:
            if str(coin1) == c2:
                volume = orders["Data"][0]["Sell"][0]["Volume"]
            else:
                volume = orders["Data"][0]["Buy"][0]["Total"]
        elif str(coin1) == c2:
            value = (1/orders["Data"][0]["Sell"][0]["Price"])

            print("sell" + str(volume))
            if volume < minimum_transaction[c2]:
                break
            if orders["Data"][0]["Sell"][0]["Volume"] > volume*value:
                volume = volume*value
            else:
                volume = orders["Data"][0]["Sell"][0]["Volume"]
        else:
            value = (orders["Data"][0]["Buy"][0]["Price"])

            if orders["Data"][0]["Buy"][0]["Total"] > volume*value:
                volume = volume*value
            else:
                volume = orders["Data"][0]["Buy"][0]["Total"]
            print("buy" + str(volume) + "min" + str(minimum_transaction[c2]))
            if volume < minimum_transaction[c2]:
                    break
        value = (1 - transaction_fee) * value

        print("BUY ORDER" + str(orders["Data"][0]["Buy"][0]))
        print("SELL ORDER" + str(orders["Data"][0]["Sell"][0]))
        print(value, volume)
    print(item, valid)

print(calls)
print(len(accumulator))
print(end - start)
